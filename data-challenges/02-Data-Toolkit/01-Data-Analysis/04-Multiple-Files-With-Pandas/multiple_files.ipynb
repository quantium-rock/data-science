# %% [markdown]
# # Multiple files with `pandas`

# %%
import numpy as np
import pandas as pd
import matplotlib

# %% [markdown]
# ## Merge Practice

# %%
a_df = pd.DataFrame({
    'Country': ['Germany', 'France', 'Belgium', 'Finland'],
    'Population (M)': [82.8, 67.2, 11.4, 5.5],
    'Capital': ['Berlin', 'Paris', 'Brussels', 'Helsinki']
})
a_df
# Out:
#    Country  Population (M)   Capital
# 0  Germany            82.8    Berlin
# 1   France            67.2     Paris
# 2  Belgium            11.4  Brussels
# 3  Finland             5.5  Helsinki

# %%
b_df = pd.DataFrame({
    'Country': ['Germany', 'France', 'Belgium', 'Canada'],
    'HDI': [0.936, 0.901, 0.916, 0.926]
})
b_df
# Out:
#    Country    HDI
# 0  Germany  0.936
# 1   France  0.901
# 2  Belgium  0.916
# 3   Canada  0.926

# %% [markdown]
# ### Inner Merge Practice

# %%
inner_merged_df = a_df.set_index('Country')
inner_merged_df = inner_merged_df.merge(b_df, on='Country')
inner_merged_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin  0.936
# 1   France            67.2     Paris  0.901
# 2  Belgium            11.4  Brussels  0.916

# %% [markdown]
# #### Check your code

# %%
from nbresult import ChallengeResult

result = ChallengeResult('inner_merge',
    inner_merged_shape=inner_merged_df.shape,
    inner_merged_nulls=sum(inner_merged_df.isnull().sum())
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.10, pytest-7.1.2, pluggy-1.0.0 -- /bin/python3
# cachedir: .pytest_cache
# rootdir: /home/quantium/labs/lewagon/data-challenges/02-Data-Toolkit/01-Data-Analysis/04-Multiple-Files-With-Pandas/tests
# plugins: dash-1.19.0
# collecting ... collected 2 items
#
# test_inner_merge.py::TestInnerMerge::test_inner_merged_nulls PASSED      [ 50%]
# test_inner_merge.py::TestInnerMerge::test_inner_merged_shape PASSED      [100%]
#
# ============================== 2 passed in 0.01s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/inner_merge.pickle
#
# git commit -m 'Completed inner_merge step'
#
# git push origin master

# %% [markdown]
# ### Left Merge Practice

# %%
left_merged_df = a_df.set_index('Country')
left_merged_df = left_merged_df.merge(b_df, how='left', on='Country')
left_merged_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin  0.936
# 1   France            67.2     Paris  0.901
# 2  Belgium            11.4  Brussels  0.916
# 3  Finland             5.5  Helsinki    NaN

# %% [markdown]
# #### Check your code

# %%
from nbresult import ChallengeResult

result = ChallengeResult('left_merge',
    left_merged_shape=left_merged_df.shape,
    left_merged_nulls=sum(left_merged_df.isnull().sum())
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.10, pytest-7.1.2, pluggy-1.0.0 -- /bin/python3
# cachedir: .pytest_cache
# rootdir: /home/quantium/labs/lewagon/data-challenges/02-Data-Toolkit/01-Data-Analysis/04-Multiple-Files-With-Pandas/tests
# plugins: dash-1.19.0
# collecting ... collected 2 items
#
# test_left_merge.py::TestLeftMerge::test_left_merged_df_shape PASSED      [ 50%]
# test_left_merge.py::TestLeftMerge::test_left_merged_nulls PASSED         [100%]
#
# ============================== 2 passed in 0.01s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/left_merge.pickle
#
# git commit -m 'Completed left_merge step'
#
# git push origin master

# %% [markdown]
# ### Right Merge Practice

# %%
right_merged_df = a_df.set_index('Country')
right_merged_df = right_merged_df.merge(b_df, how='right', on='Country')
right_merged_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin  0.936
# 1   France            67.2     Paris  0.901
# 2  Belgium            11.4  Brussels  0.916
# 3   Canada             NaN       NaN  0.926

# %% [markdown]
# #### Check your code

# %%
from nbresult import ChallengeResult

result = ChallengeResult('right_merge',
    right_merged_shape=right_merged_df.shape,
    right_merged_nulls=sum(right_merged_df.isnull().sum())
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.10, pytest-7.1.2, pluggy-1.0.0 -- /bin/python3
# cachedir: .pytest_cache
# rootdir: /home/quantium/labs/lewagon/data-challenges/02-Data-Toolkit/01-Data-Analysis/04-Multiple-Files-With-Pandas/tests
# plugins: dash-1.19.0
# collecting ... collected 2 items
#
# test_right_merge.py::TestRightMerge::test_right_merged_df_shape PASSED   [ 50%]
# test_right_merge.py::TestRightMerge::test_right_merged_nulls PASSED      [100%]
#
# ============================== 2 passed in 0.01s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/right_merge.pickle
#
# git commit -m 'Completed right_merge step'
#
# git push origin master

# %% [markdown]
# ### Outer Merge Practice

# %%
outer_merged_df = a_df.set_index('Country')
outer_merged_df = outer_merged_df.merge(b_df, how='outer', on='Country')
outer_merged_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin  0.936
# 1   France            67.2     Paris  0.901
# 2  Belgium            11.4  Brussels  0.916
# 3  Finland             5.5  Helsinki    NaN
# 4   Canada             NaN       NaN  0.926

# %% [markdown]
# #### Check your code

# %%
from nbresult import ChallengeResult

result = ChallengeResult('outer_merge',
    outer_merged_shape=outer_merged_df.shape,
    outer_merged_nulls=sum(outer_merged_df.isnull().sum())
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.10, pytest-7.1.2, pluggy-1.0.0 -- /bin/python3
# cachedir: .pytest_cache
# rootdir: /home/quantium/labs/lewagon/data-challenges/02-Data-Toolkit/01-Data-Analysis/04-Multiple-Files-With-Pandas/tests
# plugins: dash-1.19.0
# collecting ... collected 2 items
#
# test_outer_merge.py::TestOuterMerge::test_outer_merged_df_shape PASSED   [ 50%]
# test_outer_merge.py::TestOuterMerge::test_outer_merged_nulls PASSED      [100%]
#
# ============================== 2 passed in 0.01s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/outer_merge.pickle
#
# git commit -m 'Completed outer_merge step'
#
# git push origin master

# %% [markdown]
# ## Join Practice

# %%
aa_df = a_df.set_index("Country")
aa_df
# Out:
#          Population (M)   Capital
# Country
# Germany            82.8    Berlin
# France             67.2     Paris
# Belgium            11.4  Brussels
# Finland             5.5  Helsinki

# %%
bb_df = b_df.set_index("Country")
bb_df
# Out:
#            HDI
# Country
# Germany  0.936
# France   0.901
# Belgium  0.916
# Canada   0.926

# %%
aa_df.join(bb_df)
# Out:
#          Population (M)   Capital    HDI
# Country
# Germany            82.8    Berlin  0.936
# France             67.2     Paris  0.901
# Belgium            11.4  Brussels  0.916
# Finland             5.5  Helsinki    NaN

# %%
aa_df.join(bb_df, how='inner')
aa_df.join(bb_df, how='right')
aa_df.join(bb_df, how='outer')
# Out:
#          Population (M)   Capital    HDI
# Country
# Belgium            11.4  Brussels  0.916
# Canada              NaN       NaN  0.926
# Finland             5.5  Helsinki    NaN
# France             67.2     Paris  0.901
# Germany            82.8    Berlin  0.936

# %% [markdown]
# ## Concat Practice

# %%
concat_df = pd.concat([a_df, b_df], axis="index", sort=False)
concat_df
# Out:
#    Country  Population (M)   Capital    HDI
# 0  Germany            82.8    Berlin    NaN
# 1   France            67.2     Paris    NaN
# 2  Belgium            11.4  Brussels    NaN
# 3  Finland             5.5  Helsinki    NaN
# 0  Germany             NaN       NaN  0.936
# 1   France             NaN       NaN  0.901
# 2  Belgium             NaN       NaN  0.916
# 3   Canada             NaN       NaN  0.926

# %% [markdown]
# ---
#
# ## Olympic Sports and Medals, 1896-2014

# %%
countries_df = pd.read_csv('dictionary.csv')
countries_df
# Out:
#              Country Code  Population  GDP per Capita
# 0        Afghanistan  AFG  32526562.0      594.323081
# 1            Albania  ALB   2889167.0     3945.217582
# 2            Algeria  ALG  39666519.0     4206.031232
# 3    American Samoa*  ASA     55538.0             NaN
# 4            Andorra  AND     70473.0             NaN
# ..               ...  ...         ...             ...
# 196          Vietnam  VIE  91703800.0     2111.138024
# 197  Virgin Islands*  ISV    103574.0             NaN
# 198            Yemen  YEM  26832215.0     1406.291651
# 199           Zambia  ZAM  16211767.0     1304.879014
# 200         Zimbabwe  ZIM  15602751.0      924.143819
#
# [201 rows x 4 columns]

# %%
summer_df = pd.read_csv('summer.csv')
summer_df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 4             CHASAPIS, Spiridon     GRE    Men  100M Freestyle For Sailors
# ...                          ...     ...    ...                         ...
# 31160         JANIKOWSKI, Damian     POL    Men                    Wg 84 KG
# 31161  REZAEI, Ghasem Gholamreza     IRI    Men                    Wg 96 KG
# 31162             TOTROV, Rustam     RUS    Men                    Wg 96 KG
# 31163          ALEKSANYAN, Artur     ARM    Men                    Wg 96 KG
# 31164             LIDBERG, Jimmy     SWE    Men                    Wg 96 KG
#
#         Medal
# 0        Gold
# 1      Silver
# 2      Bronze
# 3        Gold
# 4      Silver
# ...       ...
# 31160  Bronze
# 31161    Gold
# 31162  Silver
# 31163  Bronze
# 31164  Bronze
#
# [31165 rows x 9 columns]

# %%
winter_df = pd.read_csv('winter.csv')
winter_df
# Out:
#       Year      City     Sport Discipline               Athlete Country  \
# 0     1924  Chamonix  Biathlon   Biathlon           BERTHET, G.     FRA
# 1     1924  Chamonix  Biathlon   Biathlon        MANDRILLON, C.     FRA
# 2     1924  Chamonix  Biathlon   Biathlon   MANDRILLON, Maurice     FRA
# 3     1924  Chamonix  Biathlon   Biathlon       VANDELLE, André     FRA
# 4     1924  Chamonix  Biathlon   Biathlon  AUFDENBLATTEN, Adolf     SUI
# ...    ...       ...       ...        ...                   ...     ...
# 5765  2014     Sochi    Skiing  Snowboard          JONES, Jenny     GBR
# 5766  2014     Sochi    Skiing  Snowboard       ANDERSON, Jamie     USA
# 5767  2014     Sochi    Skiing  Snowboard    MALTAIS, Dominique     CAN
# 5768  2014     Sochi    Skiing  Snowboard          SAMKOVA, Eva     CZE
# 5769  2014     Sochi    Skiing  Snowboard      TRESPEUCH, Chloe     FRA
#
#      Gender            Event   Medal
# 0       Men  Military Patrol  Bronze
# 1       Men  Military Patrol  Bronze
# 2       Men  Military Patrol  Bronze
# 3       Men  Military Patrol  Bronze
# 4       Men  Military Patrol    Gold
# ...     ...              ...     ...
# 5765  Women       Slopestyle  Bronze
# 5766  Women       Slopestyle    Gold
# 5767  Women  Snowboard Cross  Silver
# 5768  Women  Snowboard Cross    Gold
# 5769  Women  Snowboard Cross  Bronze
#
# [5770 rows x 9 columns]

# %% [markdown]
# ### Combining The Data

# %%
summer_countries_df = countries_df.set_index('Code')
summer_countries_df = summer_countries_df.merge(summer_df.set_index('Country'), left_index=True, right_index=True)
summer_countries_df['Season'] = 'Summer'
summer_countries_df
# Out:
#                    Country  Population  GDP per Capita  Year         City  \
# AFG            Afghanistan  32526562.0      594.323081  2008      Beijing
# AFG            Afghanistan  32526562.0      594.323081  2012       London
# AHO  Netherlands Antilles*         NaN             NaN  1988        Seoul
# ALG                Algeria  39666519.0     4206.031232  1984  Los Angeles
# ALG                Algeria  39666519.0     4206.031232  1984  Los Angeles
# ..                     ...         ...             ...   ...          ...
# ZIM               Zimbabwe  15602751.0      924.143819  2004       Athens
# ZIM               Zimbabwe  15602751.0      924.143819  2008      Beijing
# ZIM               Zimbabwe  15602751.0      924.143819  2008      Beijing
# ZIM               Zimbabwe  15602751.0      924.143819  2008      Beijing
# ZIM               Zimbabwe  15602751.0      924.143819  2008      Beijing
#
#          Sport Discipline           Athlete Gender  \
# AFG  Taekwondo  Taekwondo  NIKPAI, Rohullah    Men
# AFG  Taekwondo  Taekwondo  NIKPAI, Rohullah    Men
# AHO    Sailing    Sailing   BOERSMA, Jan D.    Men
# ALG     Boxing     Boxing    ZAOUI, Mohamed    Men
# ALG     Boxing     Boxing  MOUSSA, Mustapha    Men
# ..         ...        ...               ...    ...
# ZIM   Aquatics   Swimming  COVENTRY, Kirsty  Women
# ZIM   Aquatics   Swimming  COVENTRY, Kirsty  Women
# ZIM   Aquatics   Swimming  COVENTRY, Kirsty  Women
# ZIM   Aquatics   Swimming  COVENTRY, Kirsty  Women
# ZIM   Aquatics   Swimming  COVENTRY, Kirsty  Women
#
#                              Event   Medal  Season
# AFG                        - 58 KG  Bronze  Summer
# AFG                     58 - 68 KG  Bronze  Summer
# AHO            Board (Division Ii)  Silver  Summer
# ALG                        71-75KG  Bronze  Summer
# ALG  75 - 81KG (Light-Heavyweight)  Bronze  Summer
# ..                             ...     ...     ...
# ZIM         200M Individual Medley  Bronze  Summer
# ZIM                100M Backstroke  Silver  Summer
# ZIM                200M Backstroke    Gold  Summer
# ZIM         200M Individual Medley  Silver  Summer
# ZIM         400M Individual Medley  Silver  Summer
#
# [25742 rows x 12 columns]

# %%
winter_countries_df = countries_df.set_index('Code')
winter_countries_df = winter_countries_df.merge(winter_df.set_index('Country'), left_index=True, right_index=True)
winter_countries_df['Season'] = 'Winter'
winter_countries_df
# Out:
#            Country   Population  GDP per Capita  Year         City    Sport  \
# AUS      Australia   23781169.0    56310.962993  1994  Lillehammer  Skating
# AUS      Australia   23781169.0    56310.962993  1994  Lillehammer  Skating
# AUS      Australia   23781169.0    56310.962993  1994  Lillehammer  Skating
# AUS      Australia   23781169.0    56310.962993  1994  Lillehammer  Skating
# AUS      Australia   23781169.0    56310.962993  1998       Nagano   Skiing
# ..             ...          ...             ...   ...          ...      ...
# USA  United States  321418820.0    56115.718426  2014        Sochi   Skiing
# USA  United States  321418820.0    56115.718426  2014        Sochi   Skiing
# USA  United States  321418820.0    56115.718426  2014        Sochi   Skiing
# USA  United States  321418820.0    56115.718426  2014        Sochi   Skiing
# UZB     Uzbekistan   31299500.0     2132.070368  1994  Lillehammer   Skiing
#
#                     Discipline              Athlete Gender            Event  \
# AUS  Short Track Speed Skating     BRADBURY, Steven    Men      5000M Relay
# AUS  Short Track Speed Skating       HANSEN, Kieran    Men      5000M Relay
# AUS  Short Track Speed Skating       MURTHA, Andrew    Men      5000M Relay
# AUS  Short Track Speed Skating   NIZIELSKI, Richard    Men      5000M Relay
# AUS              Alpine Skiing       STEGGALL, Zali  Women           Slalom
# ..                         ...                  ...    ...              ...
# USA                  Snowboard        DEIBOLD, Alex    Men  Snowboard Cross
# USA                  Snowboard         CLARK, Kelly  Women        Half-Pipe
# USA                  Snowboard  FARRINGTON, Kaitlyn  Women        Half-Pipe
# USA                  Snowboard      ANDERSON, Jamie  Women       Slopestyle
# UZB           Freestyle Skiing     CHERYAZOVA, Lina  Women          Aerials
#
#       Medal  Season
# AUS  Bronze  Winter
# AUS  Bronze  Winter
# AUS  Bronze  Winter
# AUS  Bronze  Winter
# AUS  Bronze  Winter
# ..      ...     ...
# USA  Bronze  Winter
# USA  Bronze  Winter
# USA    Gold  Winter
# USA    Gold  Winter
# UZB    Gold  Winter
#
# [4826 rows x 12 columns]

# %%
all_df = pd.concat([summer_countries_df, winter_countries_df])
all_df.reset_index(inplace=True)
all_df = all_df.rename(columns={'index':'Code'})
all_df
# Out:
#       Code                Country   Population  GDP per Capita  Year  \
# 0      AFG            Afghanistan   32526562.0      594.323081  2008
# 1      AFG            Afghanistan   32526562.0      594.323081  2012
# 2      AHO  Netherlands Antilles*          NaN             NaN  1988
# 3      ALG                Algeria   39666519.0     4206.031232  1984
# 4      ALG                Algeria   39666519.0     4206.031232  1984
# ...    ...                    ...          ...             ...   ...
# 30563  USA          United States  321418820.0    56115.718426  2014
# 30564  USA          United States  321418820.0    56115.718426  2014
# 30565  USA          United States  321418820.0    56115.718426  2014
# 30566  USA          United States  321418820.0    56115.718426  2014
# 30567  UZB             Uzbekistan   31299500.0     2132.070368  1994
#
#               City      Sport        Discipline              Athlete Gender  \
# 0          Beijing  Taekwondo         Taekwondo     NIKPAI, Rohullah    Men
# 1           London  Taekwondo         Taekwondo     NIKPAI, Rohullah    Men
# 2            Seoul    Sailing           Sailing      BOERSMA, Jan D.    Men
# 3      Los Angeles     Boxing            Boxing       ZAOUI, Mohamed    Men
# 4      Los Angeles     Boxing            Boxing     MOUSSA, Mustapha    Men
# ...            ...        ...               ...                  ...    ...
# 30563        Sochi     Skiing         Snowboard        DEIBOLD, Alex    Men
# 30564        Sochi     Skiing         Snowboard         CLARK, Kelly  Women
# 30565        Sochi     Skiing         Snowboard  FARRINGTON, Kaitlyn  Women
# 30566        Sochi     Skiing         Snowboard      ANDERSON, Jamie  Women
# 30567  Lillehammer     Skiing  Freestyle Skiing     CHERYAZOVA, Lina  Women
#
#                                Event   Medal  Season
# 0                            - 58 KG  Bronze  Summer
# 1                         58 - 68 KG  Bronze  Summer
# 2                Board (Division Ii)  Silver  Summer
# 3                            71-75KG  Bronze  Summer
# 4      75 - 81KG (Light-Heavyweight)  Bronze  Summer
# ...                              ...     ...     ...
# 30563                Snowboard Cross  Bronze  Winter
# 30564                      Half-Pipe  Bronze  Winter
# 30565                      Half-Pipe    Gold  Winter
# 30566                     Slopestyle    Gold  Winter
# 30567                        Aerials    Gold  Winter
#
# [30568 rows x 13 columns]

# %% [markdown]
# #### Check your code

# %%
from nbresult import ChallengeResult

result = ChallengeResult('all_df',
    all_df_shape=all_df.shape,
    all_df_columns=set(all_df.columns)
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.10, pytest-7.1.2, pluggy-1.0.0 -- /bin/python3
# cachedir: .pytest_cache
# rootdir: /home/quantium/labs/lewagon/data-challenges/02-Data-Toolkit/01-Data-Analysis/04-Multiple-Files-With-Pandas/tests
# plugins: dash-1.19.0
# collecting ... collected 2 items
#
# test_all_df.py::TestAllDf::test_all_df_columns PASSED                    [ 50%]
# test_all_df.py::TestAllDf::test_all_df_shape PASSED                      [100%]
#
# ============================== 2 passed in 0.06s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/all_df.pickle
#
# git commit -m 'Completed all_df step'
#
# git push origin master

# %% [markdown]
# ### Top Countries Analysis

# %%
top_10_df = pd.DataFrame()
top_10_df['Country'] = all_df[ all_df['Year']>=1984 ]['Country']
top_10_df['Medal Count'] = 1
top_10_df = top_10_df.groupby('Country').count().sort_values('Medal Count', ascending=False)[:10]

top_10_df
# Out:
#                Medal Count
# Country
# United States         2472
# Germany               1112
# Russia                1031
# Australia              891
# China                  889
# Canada                 801
# Italy                  632
# Korea, South           587
# France                 587
# Netherlands            563

# %%
top_10_df.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Country'>

# %% [markdown]
# #### Check your code

# %%
from nbresult import ChallengeResult

result = ChallengeResult('olympic_games',
    top_country_1=top_10_df.iloc[0]['Medal Count'],
    top_country_10=top_10_df.iloc[9]['Medal Count']
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.10, pytest-7.1.2, pluggy-1.0.0 -- /bin/python3
# cachedir: .pytest_cache
# rootdir: /home/quantium/labs/lewagon/data-challenges/02-Data-Toolkit/01-Data-Analysis/04-Multiple-Files-With-Pandas/tests
# plugins: dash-1.19.0
# collecting ... collected 1 item
#
# test_olympic_games.py::TestOlympicGames::test_top_10_countries_medals PASSED [100%]
#
# ============================== 1 passed in 0.24s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/olympic_games.pickle
#
# git commit -m 'Completed olympic_games step'
#
# git push origin master

# %%
top_10_season_df = pd.DataFrame()

top_10_season_df['Summer'] = all_df[ all_df['Year']>=1984 ][ all_df['Season']=='Summer' ]['Country'].groupby(all_df['Country']).count()

top_10_season_df['Winter'] = all_df[ all_df['Year']>=1984 ][ all_df['Season']=='Winter' ]['Country'].groupby(all_df['Country']).count()

top_10_season_df['Total'] = top_10_season_df['Summer'] + top_10_season_df['Winter']

top_10_season_df = top_10_season_df.sort_values('Total', ascending=False)[:10]

top_10_season_df
# Out:
# <ipython-input-150-74d8e10bb998>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   top_10_season_df['Summer'] = all_df[ all_df['Year']>=1984 ][ all_df['Season']=='Summer' ]['Country'].groupby(all_df['Country']).count()
# <ipython-input-150-74d8e10bb998>:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   top_10_season_df['Winter'] = all_df[ all_df['Year']>=1984 ][ all_df['Season']=='Winter' ]['Country'].groupby(all_df['Country']).count()
#                Summer  Winter   Total
# Country
# United States    2087   385.0  2472.0
# Germany           785   327.0  1112.0
# Russia            768   263.0  1031.0
# Australia         876    15.0   891.0
# China             807    82.0   889.0
# Canada            341   460.0   801.0
# Italy             486   146.0   632.0
# Korea, South      500    87.0   587.0
# France            482   105.0   587.0
# Netherlands       476    87.0   563.0

# %%
top_10_season_df[['Summer', 'Winter']].plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Country'>

# %% [markdown]
# #### Check your code

# %%
from nbresult import ChallengeResult

result = ChallengeResult('olympic_games_season',
    top_country_season_shape=top_10_season_df.shape,
    top_country_1_summer=top_10_season_df.iloc[0]['Summer'],
    top_country_10_winter=top_10_season_df.iloc[9]['Winter']
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.10, pytest-7.1.2, pluggy-1.0.0 -- /bin/python3
# cachedir: .pytest_cache
# rootdir: /home/quantium/labs/lewagon/data-challenges/02-Data-Toolkit/01-Data-Analysis/04-Multiple-Files-With-Pandas/tests
# plugins: dash-1.19.0
# collecting ... collected 3 items
#
# test_olympic_games_season.py::TestOlympicGamesSeason::test_top_10_countries_shape PASSED [ 33%]
# test_olympic_games_season.py::TestOlympicGamesSeason::test_top_10_countries_summer PASSED [ 66%]
# test_olympic_games_season.py::TestOlympicGamesSeason::test_top_10_countries_winter PASSED [100%]
#
# ============================== 3 passed in 0.30s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/olympic_games_season.pickle
#
# git commit -m 'Completed olympic_games_season step'
#
# git push origin master

# %% [markdown]
# ### Optional - Top 10 Countries event wins since 1984

# %%
all_df[(all_df.Year==2008) & (all_df.Event=='Basketball') & (all_df.Medal=='Gold')]
# Out:
#       Code        Country   Population  GDP per Capita  Year     City  \
# 25265  USA  United States  321418820.0    56115.718426  2008  Beijing
# 25266  USA  United States  321418820.0    56115.718426  2008  Beijing
# 25267  USA  United States  321418820.0    56115.718426  2008  Beijing
# 25268  USA  United States  321418820.0    56115.718426  2008  Beijing
# 25269  USA  United States  321418820.0    56115.718426  2008  Beijing
# 25270  USA  United States  321418820.0    56115.718426  2008  Beijing
# 25271  USA  United States  321418820.0    56115.718426  2008  Beijing
# 25272  USA  United States  321418820.0    56115.718426  2008  Beijing
# 25273  USA  United States  321418820.0    56115.718426  2008  Beijing
# 25274  USA  United States  321418820.0    56115.718426  2008  Beijing
# 25275  USA  United States  321418820.0    56115.718426  2008  Beijing
# 25276  USA  United States  321418820.0    56115.718426  2008  Beijing
# 25277  USA  United States  321418820.0    56115.718426  2008  Beijing
# 25278  USA  United States  321418820.0    56115.718426  2008  Beijing
# 25279  USA  United States  321418820.0    56115.718426  2008  Beijing
# 25280  USA  United States  321418820.0    56115.718426  2008  Beijing
# 25281  USA  United States  321418820.0    56115.718426  2008  Beijing
# 25282  USA  United States  321418820.0    56115.718426  2008  Beijing
# 25283  USA  United States  321418820.0    56115.718426  2008  Beijing
# 25284  USA  United States  321418820.0    56115.718426  2008  Beijing
# 25285  USA  United States  321418820.0    56115.718426  2008  Beijing
# 25286  USA  United States  321418820.0    56115.718426  2008  Beijing
# 25287  USA  United States  321418820.0    56115.718426  2008  Beijing
# 25288  USA  United States  321418820.0    56115.718426  2008  Beijing
#
#             Sport  Discipline                Athlete Gender       Event Medal  \
# 25265  Basketball  Basketball       ANTHONY, Carmelo    Men  Basketball  Gold
# 25266  Basketball  Basketball         BOOZER, Carlos    Men  Basketball  Gold
# 25267  Basketball  Basketball            BOSH, Chris    Men  Basketball  Gold
# 25268  Basketball  Basketball           BRYANT, Kobe    Men  Basketball  Gold
# 25269  Basketball  Basketball         HOWARD, Dwight    Men  Basketball  Gold
# 25270  Basketball  Basketball          JAMES, Lebron    Men  Basketball  Gold
# 25271  Basketball  Basketball            KIDD, Jason    Men  Basketball  Gold
# 25272  Basketball  Basketball            PAUL, Chris    Men  Basketball  Gold
# 25273  Basketball  Basketball       PRINCE, Tayshaun    Men  Basketball  Gold
# 25274  Basketball  Basketball          REDD, Michael    Men  Basketball  Gold
# 25275  Basketball  Basketball           WADE, Dwyane    Men  Basketball  Gold
# 25276  Basketball  Basketball        WILLIAMS, Deron    Men  Basketball  Gold
# 25277  Basketball  Basketball      AUGUSTUS, Seimone  Women  Basketball  Gold
# 25278  Basketball  Basketball              BIRD, Sue  Women  Basketball  Gold
# 25279  Basketball  Basketball      CATCHINGS, Tamika  Women  Basketball  Gold
# 25280  Basketball  Basketball         FOWLES, Sylvia  Women  Basketball  Gold
# 25281  Basketball  Basketball           LAWSON, Kara  Women  Basketball  Gold
# 25282  Basketball  Basketball           LESLIE, Lisa  Women  Basketball  Gold
# 25283  Basketball  Basketball  MILTON-JONES, Delisha  Women  Basketball  Gold
# 25284  Basketball  Basketball        PARKER, Candace  Women  Basketball  Gold
# 25285  Basketball  Basketball      PONDEXTER, Cappie  Women  Basketball  Gold
# 25286  Basketball  Basketball           SMITH, Katie  Women  Basketball  Gold
# 25287  Basketball  Basketball         TAURASI, Diana  Women  Basketball  Gold
# 25288  Basketball  Basketball         THOMPSON, Tina  Women  Basketball  Gold
#
#        Season
# 25265  Summer
# 25266  Summer
# 25267  Summer
# 25268  Summer
# 25269  Summer
# 25270  Summer
# 25271  Summer
# 25272  Summer
# 25273  Summer
# 25274  Summer
# 25275  Summer
# 25276  Summer
# 25277  Summer
# 25278  Summer
# 25279  Summer
# 25280  Summer
# 25281  Summer
# 25282  Summer
# 25283  Summer
# 25284  Summer
# 25285  Summer
# 25286  Summer
# 25287  Summer
# 25288  Summer

# %%
top_10_events_df = pd.DataFrame()

top_10_events_df['Event Count'] = all_df[ (all_df['Year']>=1984) ]['Event']

top_10_events_df['Event Count'] = all_df[ (all_df['Year']>=1984) ]['Event'].groupby(all_df['Event']).count()

top_10_events_df = top_10_events_df.sort_values('Event Count', ascending=False)[:10]

top_10_events_df
# Out:
#    Event Count
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN

# %%
top_10_events_df.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Event'>

# %% [markdown]
# #### Check your code

# %%
from nbresult import ChallengeResult

result = ChallengeResult('olympic_games_event',
    top_country_event_shape=top_10_events_df.shape,
    top_country_1_event=top_10_events_df.iloc[0]['Event Count'],
    top_country_10_event=top_10_events_df.iloc[9]['Event Count']
)
result.write()

print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.10, pytest-7.1.2, pluggy-1.0.0 -- /bin/python3
# cachedir: .pytest_cache
# rootdir: /home/quantium/labs/lewagon/data-challenges/02-Data-Toolkit/01-Data-Analysis/04-Multiple-Files-With-Pandas/tests
# plugins: dash-1.19.0
# collecting ... collected 3 items
#
# test_olympic_games_event.py::TestOlympicGamesEvent::test_top_10_events_shape PASSED [ 33%]
# test_olympic_games_event.py::TestOlympicGamesEvent::test_top_events_1 FAILED [ 66%]
# test_olympic_games_event.py::TestOlympicGamesEvent::test_top_events_10 FAILED [100%]
#
# =================================== FAILURES ===================================
# ___________________ TestOlympicGamesEvent.test_top_events_1 ____________________
#
# self = <test_olympic_games_event.TestOlympicGamesEvent testMethod=test_top_events_1>
#
#     def test_top_events_1(self):
# >       self.assertEqual(self.result.top_country_1_event, 1078)
# E       AssertionError: 814 != 1078
#
# test_olympic_games_event.py:9: AssertionError
# ___________________ TestOlympicGamesEvent.test_top_events_10 ___________________
#
# self = <test_olympic_games_event.TestOlympicGamesEvent testMethod=test_top_events_10>
#
#     def test_top_events_10(self):
# >       self.assertEqual(self.result.top_country_10_event, 281)
# E       AssertionError: 290 != 281
#
# test_olympic_games_event.py:12: AssertionError
# =========================== short test summary info ============================
# FAILED test_olympic_games_event.py::TestOlympicGamesEvent::test_top_events_1
# FAILED test_olympic_games_event.py::TestOlympicGamesEvent::test_top_events_10
# ========================= 2 failed, 1 passed in 0.46s ==========================
#
#
# 💯 You can commit your code:
#
# git add tests/olympic_games_event.pickle
#
# git commit -m 'Completed olympic_games_event step'
#
# git push origin master
